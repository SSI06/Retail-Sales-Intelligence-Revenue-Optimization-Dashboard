# %%
import pandas as pd

# %% [markdown]
#  LOAD DATA

# %%
df = pd.read_csv("cleaned_sales_data.csv")
df['order_date'] = pd.to_datetime(df['order_date'])

# %% [markdown]
# KPIs

# %%
# 1. Total Revenue
total_revenue = df['sales'].sum()

# %%
# 2. Total Profit
total_profit = df['profit'].sum()

# %%
# 3. Average Order Value (AOV)
avg_order_value = df['sales'].mean()

# %%
# 4. Total Orders
total_orders = df['order_id'].nunique()

# %%
# 5. Profit Margin %
profit_margin = (total_profit / total_revenue) * 100

# %%
# 6. Monthly Growth Rate
df['month'] = df['order_date'].dt.to_period('M')
monthly_sales = df.groupby('month')['sales'].sum()
growth_rate = monthly_sales.pct_change().mean() * 100

# %%
print("\nKPI RESULTS")
print("---------------------------")
print(f"Total Revenue: {total_revenue:,.2f}")
print(f"Total Profit: {total_profit:,.2f}")
print(f"Total Orders: {total_orders}")
print(f"Average Order Value: {avg_order_value:,.2f}")
print(f"Profit Margin: {profit_margin:.2f}%")
print(f"Average Monthly Growth Rate: {growth_rate:.2f}%")
# Out:
# KPI RESULTS
# ---------------------------
# Total Revenue: 1,989,442,700.00
# Total Profit: 498,360,325.35
# Total Orders: 50000
# Average Order Value: 39,788.85
# Profit Margin: 25.05%
# Average Monthly Growth Rate: -0.25%
